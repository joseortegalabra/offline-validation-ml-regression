# %% [markdown]
# # INSTALL PACKAGES EXPLANAIBLE AI

# %% [markdown]
# ### 1. Try install alibi

# %%
# !pip install alibi

# %% [markdown]
# ### 2. SHAP

# %%
# !pip install shap

# %% [markdown]
# ### 3. SHAPASH
# See this package force install a previous version of flask (this may genereate problems if you use this env to create flask apps)

# %%
# !pip install shapash
# Out:
# Collecting shapash
#   Downloading shapash-2.4.2-py2.py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: plotly>=5.0.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from shapash) (5.17.0)
# Requirement already satisfied: matplotlib>=3.2.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from shapash) (3.8.0)
# Requirement already satisfied: numpy>1.18.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from shapash) (1.23.5)
# Requirement already satisfied: pandas>1.0.2 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from shapash) (2.0.3)
# Requirement already satisfied: shap>=0.38.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from shapash) (0.44.0)
# Collecting Flask<2.3.0 (from shapash)
#   Using cached Flask-2.2.5-py3-none-any.whl (101 kB)
# Collecting dash>=2.3.1 (from shapash)
#   Downloading dash-2.15.0-py3-none-any.whl.metadata (11 kB)
# Collecting dash-bootstrap-components>=1.1.0 (from shapash)
#   Downloading dash_bootstrap_components-1.5.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting dash-core-components>=2.0.0 (from shapash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-daq>=0.5.0 (from shapash)
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      ------------------ ------------------- 317.4/642.7 kB 9.9 MB/s eta 0:00:01
#      ------------------------------------  634.9/642.7 kB 13.3 MB/s eta 0:00:01
#      -------------------------------------- 642.7/642.7 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dash-html-components>=2.0.0 (from shapash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-renderer==1.8.3 (from shapash)
#   Downloading dash_renderer-1.8.3.tar.gz (1.0 MB)
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      ---------------------------------------  1.0/1.0 MB ? eta -:--:--
#      ---------------------------------------- 1.0/1.0 MB 21.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dash-table>=5.0.0 (from shapash)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: nbformat>4.2.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from shapash) (5.9.2)
# Requirement already satisfied: numba>=0.53.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from shapash) (0.58.1)
# Requirement already satisfied: scikit-learn<1.4,>=1.0.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from shapash) (1.3.1)
# Collecting category-encoders>=2.6.0 (from shapash)
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: scipy>=0.19.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from shapash) (1.11.3)
# Requirement already satisfied: statsmodels>=0.9.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from category-encoders>=2.6.0->shapash) (0.14.1)
# Requirement already satisfied: patsy>=0.5.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from category-encoders>=2.6.0->shapash) (0.5.5)
# Requirement already satisfied: Werkzeug<3.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from dash>=2.3.1->shapash) (3.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from dash>=2.3.1->shapash) (4.8.0)
# Requirement already satisfied: requests in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from dash>=2.3.1->shapash) (2.31.0)
# Collecting retrying (from dash>=2.3.1->shapash)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: nest-asyncio in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from dash>=2.3.1->shapash) (1.5.8)
# Requirement already satisfied: setuptools in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from dash>=2.3.1->shapash) (68.2.2)
# Requirement already satisfied: importlib-metadata in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from dash>=2.3.1->shapash) (6.8.0)
# Requirement already satisfied: Jinja2>=3.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from Flask<2.3.0->shapash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from Flask<2.3.0->shapash) (2.1.2)
# Requirement already satisfied: click>=8.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from Flask<2.3.0->shapash) (8.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib>=3.2.0->shapash) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib>=3.2.0->shapash) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib>=3.2.0->shapash) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib>=3.2.0->shapash) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib>=3.2.0->shapash) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib>=3.2.0->shapash) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib>=3.2.0->shapash) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib>=3.2.0->shapash) (2.8.2)
# Requirement already satisfied: fastjsonschema in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from nbformat>4.2.0->shapash) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from nbformat>4.2.0->shapash) (4.19.1)
# Requirement already satisfied: jupyter-core in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from nbformat>4.2.0->shapash) (5.4.0)
# Requirement already satisfied: traitlets>=5.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from nbformat>4.2.0->shapash) (5.12.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from numba>=0.53.1->shapash) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from pandas>1.0.2->shapash) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from pandas>1.0.2->shapash) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from plotly>=5.0.0->shapash) (8.2.3)
# Requirement already satisfied: joblib>=1.1.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-learn<1.4,>=1.0.1->shapash) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-learn<1.4,>=1.0.1->shapash) (3.2.0)
# Requirement already satisfied: tqdm>=4.27.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from shap>=0.38.1->shapash) (4.66.1)
# Requirement already satisfied: slicer==0.0.7 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from shap>=0.38.1->shapash) (0.0.7)
# Requirement already satisfied: cloudpickle in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from shap>=0.38.1->shapash) (2.2.1)
# Requirement already satisfied: colorama in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from click>=8.0->Flask<2.3.0->shapash) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from Jinja2>=3.0->Flask<2.3.0->shapash) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from jsonschema>=2.6->nbformat>4.2.0->shapash) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from jsonschema>=2.6->nbformat>4.2.0->shapash) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from jsonschema>=2.6->nbformat>4.2.0->shapash) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from jsonschema>=2.6->nbformat>4.2.0->shapash) (0.10.6)
# Requirement already satisfied: six in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.6.0->shapash) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from importlib-metadata->dash>=2.3.1->shapash) (3.17.0)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from jupyter-core->nbformat>4.2.0->shapash) (3.11.0)
# Requirement already satisfied: pywin32>=300 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from jupyter-core->nbformat>4.2.0->shapash) (306)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from requests->dash>=2.3.1->shapash) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from requests->dash>=2.3.1->shapash) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from requests->dash>=2.3.1->shapash) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from requests->dash>=2.3.1->shapash) (2023.7.22)
# Downloading shapash-2.4.2-py2.py3-none-any.whl (651 kB)
#    ---------------------------------------- 0.0/651.8 kB ? eta -:--:--
#    --------------------------------------- 651.8/651.8 kB 20.7 MB/s eta 0:00:00
# Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ----------------------------------- ---- 71.7/81.9 kB ? eta -:--:--
#    ---------------------------------------- 81.9/81.9 kB 1.5 MB/s eta 0:00:00
# Downloading dash-2.15.0-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ----------------- ---------------------- 4.6/10.2 MB 146.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.7/10.2 MB 93.5 MB/s eta 0:00:01
#    ---------------------------------------  10.2/10.2 MB 109.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 65.4 MB/s eta 0:00:00
# Downloading dash_bootstrap_components-1.5.0-py3-none-any.whl (221 kB)
#    ---------------------------------------- 0.0/221.2 kB ? eta -:--:--
#    -------------------------------------- - 215.0/221.2 kB ? eta -:--:--
#    ---------------------------------------- 221.2/221.2 kB 4.5 MB/s eta 0:00:00
# Building wheels for collected packages: dash-renderer, dash-daq
#   Building wheel for dash-renderer (setup.py): started
#   Building wheel for dash-renderer (setup.py): finished with status 'done'
#   Created wheel for dash-renderer: filename=dash_renderer-1.8.3-py3-none-any.whl size=1013926 sha256=d7257a004b260a98f9da267a29370b0b57050593566067a5c10c32bbc0825781
#   Stored in directory: c:\users\jortegal\appdata\local\pip\cache\wheels\6c\04\c8\22a0b5a26c3ecb61e17a27d4bbe7fad32d1417bbdbd4d46acf
#   Building wheel for dash-daq (setup.py): started
#   Building wheel for dash-daq (setup.py): finished with status 'done'
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669719 sha256=58134b5ba6ca3a6f2e95f8bd9de1f8afd7b7e98f1f314d3fbb999bb325c26308
#   Stored in directory: c:\users\jortegal\appdata\local\pip\cache\wheels\75\14\1b\208d09d5e239391048bdc167759977b41ba65a3d4063aebf6b
# Successfully built dash-renderer dash-daq
# Installing collected packages: dash-table, dash-renderer, dash-html-components, dash-core-components, retrying, Flask, dash, dash-daq, dash-bootstrap-components, category-encoders, shapash
#   Attempting uninstall: Flask
#     Found existing installation: Flask 2.3.3
#     Uninstalling Flask-2.3.3:
#       Successfully uninstalled Flask-2.3.3
# Successfully installed Flask-2.2.5 category-encoders-2.6.3 dash-2.15.0 dash-bootstrap-components-1.5.0 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-renderer-1.8.3 dash-table-5.0.0 retrying-1.3.4 shapash-2.4.2

# %% [markdown]
# ### 4. OLD PACKAGES
# "OLD" because is is packages that are not updated in pip recently. This doesn't mean these packages doesn't works but there are some risks

# %% [markdown]
# #### 4.1 eli5

# %%
# !pip install eli5
# Out:
# Requirement already satisfied: eli5 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (0.13.0)
# Requirement already satisfied: attrs>17.1.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from eli5) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from eli5) (3.1.2)
# Requirement already satisfied: numpy>=1.9.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from eli5) (1.23.5)
# Requirement already satisfied: scipy in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from eli5) (1.11.3)
# Requirement already satisfied: six in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from eli5) (1.16.0)
# Requirement already satisfied: scikit-learn>=0.20 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from eli5) (1.3.1)
# Requirement already satisfied: graphviz in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from eli5) (0.20.1)
# Requirement already satisfied: tabulate>=0.7.7 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from eli5) (0.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from jinja2>=3.0.0->eli5) (2.1.3)
# Requirement already satisfied: joblib>=1.1.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-learn>=0.20->eli5) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-learn>=0.20->eli5) (3.2.0)

# %% [markdown]
# #### 4.2 lime

# %%
# !pip install lime
# Out:
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ---------------------------------------- 0.0/275.7 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/275.7 kB 660.6 kB/s eta 0:00:01
#      ---------------------------- --------- 204.8/275.7 kB 2.5 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/275.7 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ 275.7/275.7 kB 180.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from lime) (3.8.0)
# Requirement already satisfied: numpy in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from lime) (1.23.5)
# Requirement already satisfied: scipy in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from lime) (1.11.3)
# Requirement already satisfied: tqdm in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from lime) (4.66.1)
# Requirement already satisfied: scikit-learn>=0.18 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from lime) (1.3.1)
# Requirement already satisfied: scikit-image>=0.12 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from lime) (0.22.0)
# Requirement already satisfied: networkx>=2.8 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-image>=0.12->lime) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-image>=0.12->lime) (10.1.0)
# Requirement already satisfied: imageio>=2.27 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-image>=0.12->lime) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-image>=0.12->lime) (2024.1.30)
# Requirement already satisfied: packaging>=21 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-image>=0.12->lime) (23.2)
# Requirement already satisfied: lazy_loader>=0.3 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-image>=0.12->lime) (0.3)
# Requirement already satisfied: joblib>=1.1.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-learn>=0.18->lime) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-learn>=0.18->lime) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib->lime) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib->lime) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib->lime) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib->lime) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: colorama in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from tqdm->lime) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py): started
#   Building wheel for lime (setup.py): finished with status 'done'
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283842 sha256=cf48e37f368ac3df9d7580ffade9625b5a527830d6cf376628515ce2fc78ebee
#   Stored in directory: c:\users\jortegal\appdata\local\pip\cache\wheels\fd\a2\af\9ac0a1a85a27f314a06b39e1f492bee1547d52549a4606ed89
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1

# %% [markdown]
# #### 4.3 skater - last update 21 sept 2018
# I CANT INSTALL, TOO OLD

# %%
# !pip install skater
# Out:
# Collecting skater
#   Downloading skater-1.1.2.tar.gz (96 kB)
#      ---------------------------------------- 0.0/96.7 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/96.7 kB ? eta -:--:--
#      -------------------------------- ----- 81.9/96.7 kB 919.0 kB/s eta 0:00:01
#      -------------------------------------- 96.7/96.7 kB 692.0 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scikit-learn>=0.18 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from skater) (1.3.1)
# Collecting scikit-image==0.14 (from skater)
#   Downloading scikit-image-0.14.0.tar.gz (27.0 MB)
#      ---------------------------------------- 0.0/27.0 MB ? eta -:--:--
#       --------------------------------------- 0.5/27.0 MB 16.3 MB/s eta 0:00:02
#      - -------------------------------------- 1.0/27.0 MB 22.0 MB/s eta 0:00:02
#      - -------------------------------------- 1.0/27.0 MB 22.0 MB/s eta 0:00:02
#      -- ------------------------------------- 1.4/27.0 MB 8.1 MB/s eta 0:00:04
#      --- ------------------------------------ 2.1/27.0 MB 11.1 MB/s eta 0:00:03
#      --- ------------------------------------ 2.1/27.0 MB 11.1 MB/s eta 0:00:03
#      --- ------------------------------------ 2.2/27.0 MB 6.9 MB/s eta 0:00:04
#      ---- ----------------------------------- 3.1/27.0 MB 9.6 MB/s eta 0:00:03
#      ---- ----------------------------------- 3.1/27.0 MB 9.6 MB/s eta 0:00:03
#      ---- ----------------------------------- 3.1/27.0 MB 9.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------ --------------------------------- 4.2/27.0 MB 8.6 MB/s eta 0:00:03
#      ------- -------------------------------- 4.8/27.0 MB 3.8 MB/s eta 0:00:06
#      ------- -------------------------------- 5.2/27.0 MB 4.2 MB/s eta 0:00:06
#      ------- -------------------------------- 5.2/27.0 MB 4.2 MB/s eta 0:00:06
#      ------- -------------------------------- 5.2/27.0 MB 4.2 MB/s eta 0:00:06
#      ------- -------------------------------- 5.2/27.0 MB 4.2 MB/s eta 0:00:06
#      ------- -------------------------------- 5.2/27.0 MB 4.2 MB/s eta 0:00:06
#      ------- -------------------------------- 5.2/27.0 MB 4.2 MB/s eta 0:00:06
#      --------- ------------------------------ 6.3/27.0 MB 4.0 MB/s eta 0:00:06
#      --------- ------------------------------ 6.3/27.0 MB 4.0 MB/s eta 0:00:06
#      --------- ------------------------------ 6.3/27.0 MB 4.0 MB/s eta 0:00:06
#      ---------- ----------------------------- 7.3/27.0 MB 4.3 MB/s eta 0:00:05
#      ---------- ----------------------------- 7.3/27.0 MB 4.3 MB/s eta 0:00:05
#      ---------- ----------------------------- 7.3/27.0 MB 4.3 MB/s eta 0:00:05
#      ------------ --------------------------- 8.4/27.0 MB 4.5 MB/s eta 0:00:05
#      ------------ --------------------------- 8.4/27.0 MB 4.5 MB/s eta 0:00:05
#      ------------ --------------------------- 8.4/27.0 MB 4.5 MB/s eta 0:00:05
#      ------------- -------------------------- 8.8/27.0 MB 4.4 MB/s eta 0:00:05
#      ------------- -------------------------- 9.4/27.0 MB 4.7 MB/s eta 0:00:04
#      ------------- -------------------------- 9.4/27.0 MB 4.7 MB/s eta 0:00:04
#      ------------- -------------------------- 9.4/27.0 MB 4.7 MB/s eta 0:00:04
#      --------------- ------------------------ 10.5/27.0 MB 4.8 MB/s eta 0:00:04
#      --------------- ------------------------ 10.5/27.0 MB 4.8 MB/s eta 0:00:04
#      --------------- ------------------------ 10.5/27.0 MB 4.8 MB/s eta 0:00:04
#      --------------- ------------------------ 10.5/27.0 MB 4.8 MB/s eta 0:00:04
#      --------------- ------------------------ 10.5/27.0 MB 4.8 MB/s eta 0:00:04
#      --------------- ------------------------ 10.5/27.0 MB 4.8 MB/s eta 0:00:04
#      --------------- ------------------------ 10.5/27.0 MB 4.8 MB/s eta 0:00:04
#      --------------- ------------------------ 10.5/27.0 MB 4.8 MB/s eta 0:00:04
#      --------------- ------------------------ 10.5/27.0 MB 4.8 MB/s eta 0:00:04
#      ----------------- ---------------------- 11.5/27.0 MB 4.3 MB/s eta 0:00:04
#      ----------------- ---------------------- 11.5/27.0 MB 4.3 MB/s eta 0:00:04
#      ----------------- ---------------------- 11.5/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------ --------------------- 12.6/27.0 MB 4.3 MB/s eta 0:00:04
#      ------------------- -------------------- 13.2/27.0 MB 2.9 MB/s eta 0:00:05
#      -------------------- ------------------- 13.6/27.0 MB 3.0 MB/s eta 0:00:05
#      -------------------- ------------------- 13.6/27.0 MB 3.0 MB/s eta 0:00:05
#      -------------------- ------------------- 13.6/27.0 MB 3.0 MB/s eta 0:00:05
#      --------------------- ------------------ 14.7/27.0 MB 3.7 MB/s eta 0:00:04
#      --------------------- ------------------ 14.7/27.0 MB 3.7 MB/s eta 0:00:04
#      --------------------- ------------------ 14.7/27.0 MB 3.7 MB/s eta 0:00:04
#      ----------------------- ---------------- 15.7/27.0 MB 3.9 MB/s eta 0:00:03
#      ----------------------- ---------------- 15.7/27.0 MB 3.9 MB/s eta 0:00:03
#      ----------------------- ---------------- 15.7/27.0 MB 3.9 MB/s eta 0:00:03
#      ------------------------ --------------- 16.7/27.0 MB 3.9 MB/s eta 0:00:03
#      ------------------------ --------------- 16.8/27.0 MB 3.9 MB/s eta 0:00:03
#      ------------------------ --------------- 16.8/27.0 MB 3.9 MB/s eta 0:00:03
#      ------------------------ --------------- 16.8/27.0 MB 3.9 MB/s eta 0:00:03
#      ------------------------ --------------- 16.8/27.0 MB 3.9 MB/s eta 0:00:03
#      ------------------------ --------------- 16.8/27.0 MB 3.9 MB/s eta 0:00:03
#      ------------------------ --------------- 16.8/27.0 MB 3.9 MB/s eta 0:00:03
#      -------------------------- ------------- 17.8/27.0 MB 3.7 MB/s eta 0:00:03
#      -------------------------- ------------- 17.8/27.0 MB 3.7 MB/s eta 0:00:03
#      --------------------------- ------------ 18.7/27.0 MB 3.7 MB/s eta 0:00:03
#      --------------------------- ------------ 18.9/27.0 MB 3.8 MB/s eta 0:00:03
#      --------------------------- ------------ 18.9/27.0 MB 3.8 MB/s eta 0:00:03
#      --------------------------- ------------ 18.9/27.0 MB 3.8 MB/s eta 0:00:03
#      ----------------------------- ---------- 19.9/27.0 MB 3.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 19.9/27.0 MB 3.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 19.9/27.0 MB 3.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 19.9/27.0 MB 3.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 19.9/27.0 MB 3.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 19.9/27.0 MB 3.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 19.9/27.0 MB 3.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 19.9/27.0 MB 3.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 19.9/27.0 MB 3.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 19.9/27.0 MB 3.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 19.9/27.0 MB 3.7 MB/s eta 0:00:02
#      ------------------------------ --------- 20.6/27.0 MB 3.1 MB/s eta 0:00:03
#      ------------------------------- -------- 21.0/27.0 MB 3.6 MB/s eta 0:00:02
#      ------------------------------- -------- 21.0/27.0 MB 3.6 MB/s eta 0:00:02
#      ------------------------------- -------- 21.0/27.0 MB 3.6 MB/s eta 0:00:02
#      ------------------------------- -------- 21.0/27.0 MB 3.6 MB/s eta 0:00:02
#      ------------------------------- -------- 21.0/27.0 MB 3.6 MB/s eta 0:00:02
#      ------------------------------- -------- 21.0/27.0 MB 3.6 MB/s eta 0:00:02
#      ------------------------------- -------- 21.0/27.0 MB 3.6 MB/s eta 0:00:02
#      ------------------------------- -------- 21.0/27.0 MB 3.6 MB/s eta 0:00:02
#      ------------------------------- -------- 21.5/27.0 MB 3.1 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      -------------------------------- ------- 22.0/27.0 MB 3.3 MB/s eta 0:00:02
#      ---------------------------------- ----- 23.1/27.0 MB 3.1 MB/s eta 0:00:02
#      ---------------------------------- ----- 23.1/27.0 MB 3.1 MB/s eta 0:00:02
#      ---------------------------------- ----- 23.1/27.0 MB 3.1 MB/s eta 0:00:02
#      ---------------------------------- ----- 23.1/27.0 MB 3.1 MB/s eta 0:00:02
#      ---------------------------------- ----- 23.1/27.0 MB 3.1 MB/s eta 0:00:02
#      ---------------------------------- ----- 23.1/27.0 MB 3.1 MB/s eta 0:00:02
#      ----------------------------------- ---- 24.1/27.0 MB 3.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 24.1/27.0 MB 3.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 24.1/27.0 MB 3.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 24.1/27.0 MB 3.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 24.1/27.0 MB 3.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 24.1/27.0 MB 3.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 24.1/27.0 MB 3.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 24.1/27.0 MB 3.0 MB/s eta 0:00:01
#      ------------------------------------- -- 25.2/27.0 MB 2.8 MB/s eta 0:00:01
#      ------------------------------------- -- 25.2/27.0 MB 2.8 MB/s eta 0:00:01
#      ------------------------------------- -- 25.2/27.0 MB 2.8 MB/s eta 0:00:01
#      ---------------------------------------  27.0/27.0 MB 2.8 MB/s eta 0:00:01
#      ---------------------------------------  27.0/27.0 MB 2.8 MB/s eta 0:00:01
#      ---------------------------------------- 27.0/27.0 MB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [58 lines of output]
#   C:\Users\JORTEGAL\AppData\Local\Temp\pip-install-61b_p0x9\scikit-image_1c3f264232df47ada75039a0fe2a43e3\setup.py:78: DeprecationWarning:
#
#     `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#     of the deprecation of `distutils` itself. It will be removed for
#     Python >= 3.12. For older Python versions it will remain present.
#     It is recommended to use `setuptools < 60.0` for those Python versions.
#     For more details, see:
#       https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#     from numpy.distutils.core import setup
#   Partial import of skimage during the build process.
#   Traceback (most recent call last):
#     File "C:\Users\JORTEGAL\AppData\Local\Temp\pip-install-61b_p0x9\scikit-image_1c3f264232df47ada75039a0fe2a43e3\skimage\_build.py", line 30, in cython
#       from Cython import __version__
#   ModuleNotFoundError: No module named 'Cython'
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\JORTEGAL\AppData\Local\Temp\pip-install-61b_p0x9\scikit-image_1c3f264232df47ada75039a0fe2a43e3\setup.py", line 111, in <module>
#       setup(
#     File "D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\numpy\distutils\core.py", line 135, in setup
#       config = configuration()
#     File "C:\Users\JORTEGAL\AppData\Local\Temp\pip-install-61b_p0x9\scikit-image_1c3f264232df47ada75039a0fe2a43e3\setup.py", line 70, in configuration
#       config.add_subpackage('skimage')
#     File "D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\numpy\distutils\misc_util.py", line 1050, in add_subpackage
#       config_list = self.get_subpackage(subpackage_name, subpackage_path,
#     File "D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\numpy\distutils\misc_util.py", line 1016, in get_subpackage
#       config = self._get_configuration_from_setup_py(
#     File "D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\numpy\distutils\misc_util.py", line 958, in _get_configuration_from_setup_py
#       config = setup_module.configuration(*args)
#     File "C:\Users\JORTEGAL\AppData\Local\Temp\pip-install-61b_p0x9\scikit-image_1c3f264232df47ada75039a0fe2a43e3\skimage\setup.py", line 14, in configuration
#       config.add_subpackage('feature')
#     File "D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\numpy\distutils\misc_util.py", line 1050, in add_subpackage
#       config_list = self.get_subpackage(subpackage_name, subpackage_path,
#     File "D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\numpy\distutils\misc_util.py", line 1016, in get_subpackage
#       config = self._get_configuration_from_setup_py(
#     File "D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\numpy\distutils\misc_util.py", line 958, in _get_configuration_from_setup_py
#       config = setup_module.configuration(*args)
#     File "C:\Users\JORTEGAL\AppData\Local\Temp\pip-install-61b_p0x9\scikit-image_1c3f264232df47ada75039a0fe2a43e3\skimage\feature\setup.py", line 22, in configuration
#       cython(['_haar.pyx'], working_path=base_path)
#     File "C:\Users\JORTEGAL\AppData\Local\Temp\pip-install-61b_p0x9\scikit-image_1c3f264232df47ada75039a0fe2a43e3\skimage\_build.py", line 41, in cython
#       raise RuntimeError('Cython >= %s is required to build scikit-image from git checkout' \
#   RuntimeError: Cython >= 0.23 is required to build scikit-image from git checkout
#   Cython >= 0.23 not found; falling back to pre-built geometry.c
#   Cython >= 0.23 not found; falling back to pre-built transform.c
#   Cython >= 0.23 not found; falling back to pre-built interpolation.c
#   Cython >= 0.23 not found; falling back to pre-built _draw.c
#   Cython >= 0.23 not found; falling back to pre-built corner_cy.c
#   Cython >= 0.23 not found; falling back to pre-built censure_cy.c
#   Cython >= 0.23 not found; falling back to pre-built orb_cy.c
#   Cython >= 0.23 not found; falling back to pre-built brief_cy.c
#   Cython >= 0.23 not found; falling back to pre-built _texture.c
#   Cython >= 0.23 not found; falling back to pre-built _hessian_det_appx.c
#   Cython >= 0.23 not found; falling back to pre-built _hoghistogram.c
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip show skater
# Out:
# WARNING: Package(s) not found: skater

# %% [markdown]
# #### 4.4 Skopes-rule

# %%
# !pip install skope-rules
# Out:
# Collecting skope-rules
#   Downloading skope_rules-1.0.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.10.4 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from skope-rules) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.17.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from skope-rules) (1.3.1)
# Requirement already satisfied: scipy>=0.17.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from skope-rules) (1.11.3)
# Requirement already satisfied: pandas>=0.18.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from skope-rules) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from pandas>=0.18.1->skope-rules) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from pandas>=0.18.1->skope-rules) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from pandas>=0.18.1->skope-rules) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-learn>=0.17.1->skope-rules) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from scikit-learn>=0.17.1->skope-rules) (3.2.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.18.1->skope-rules) (1.16.0)
# Installing collected packages: skope-rules
# Successfully installed skope-rules-1.0.1
